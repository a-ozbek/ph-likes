# %%
import numpy as np
import pandas as pd
from ph_likes.util import queries
# Out:
# /home/can/anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
x = np.full((766682, 63274), False, dtype=np.bool)

# %%
x = None

# %%
# df_user = queries.get_phuser_table()
# df_post = queries.get_post_table()
df_postlike = queries.get_postlike_table()

# %%
df_postlike
# Out:
#                 id  post_id  user_id
# 0                1        1        1
# 1                2        1        2
# 2                3        1        3
# 3                4        1        4
# 4                5        1        5
# 5                6        1        6
# 6                7        1        7
# 7                8        1        8
# 8                9        1        9
# 9               10        1       10
# 10              11        1       11
# 11              12        1       12
# 12              13        1       13
# 13              14        1       14
# 14              15        1       15
# 15              16        1       16
# 16              17        1       17
# 17              18        1       18
# 18              19        1       19
# 19              20        1       20
# 20              21        1       21
# 21              22        1       22
# 22              23        1       23
# 23              24        1       24
# ...

# %%
df_postlike['rating'] = True

# %%
df_postlike_ = df_postlike.sample(n=1000000)

# %%
# %%time
df_cf = df_postlike_.pivot_table(index='user_id', columns='post_id', values='rating', fill_value=False)

# %%
df_cf
