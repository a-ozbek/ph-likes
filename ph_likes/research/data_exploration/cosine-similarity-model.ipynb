# %%
import itertools
from ph_likes.util import queries
from ph_likes.post_similarity.cosine_post_similarity import CosinePostSimilarity
# Out:
# /home/can/anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# Load model
# model = CosinePostSimilarity()

# %%
df_post = queries.get_post_table()

# %%
df_post
# Out:
#           id                          created   ph_id         ph_enc_id  \
# 0        467 2019-01-27 18:44:36.676004+00:00  142385  UG9zdC0xNDIzODU=
# 1       8662 2019-01-27 19:02:48.735322+00:00  118856  UG9zdC0xMTg4NTY=
# 2        469 2019-01-27 18:44:36.692509+00:00  142380  UG9zdC0xNDIzODA=
# 3      49347 2019-01-27 20:02:12.613879+00:00   20086  UG9zdC0yMDA4Ng==
# 4      49353 2019-01-27 20:02:12.664743+00:00   20045  UG9zdC0yMDA0NQ==
# 5      49354 2019-01-27 20:02:12.672797+00:00   20100  UG9zdC0yMDEwMA==
# 6        473 2019-01-27 18:44:36.726909+00:00  142351  UG9zdC0xNDIzNTE=
# 7      49361 2019-01-27 20:02:12.730591+00:00   20150  UG9zdC0yMDE1MA==
# 8      49368 2019-01-27 20:02:12.791939+00:00   20160  UG9zdC0yMDE2MA==
# 9       3407 2019-01-27 18:47:54.084165+00:00  134033  UG9zdC0xMzQwMzM=
# 10      8663 2019-01-27 19:02:48.743919+00:00  118829  UG9zdC0xMTg4Mjk=
# 11       173 2019-01-27 18:44:19.120057+00:00  143132  UG9zdC0xNDMxMzI=
# ...

# %%
post_id_1 = 10
post_id_2 = 20
tagline1 = df_post[df_post['id'] == post_id_1]['tagline'].iloc[0]
tagline2 = df_post[df_post['id'] == post_id_2]['tagline'].iloc[0]
print(tagline1)
print("***")
print(tagline2)
print('similarity:', model.get_similarity(post_id_1, post_id_2))
print(" ")
# Out:
# Puzzle adventure where you control 2 characters.
# ***
# Spread the fun by doing location based fun challenges
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-09dadd6d9a42> in <module>()
#       6 print("***")
#       7 print(tagline2)
# ----> 8 print('similarity:', model.get_similarity(post_id_1, post_id_2))
#       9 print(" ")
#
# NameError: name 'model' is not defined

# %%
# sample post_ids
post_ids = df_post['id'].sample(n=100).values
post_ids_comb = itertools.combinations(post_ids, 2)
for post_id_1, post_id_2 in post_ids_comb:
    tagline1 = df_post[df_post['id'] == post_id_1]['tagline'].iloc[0]
    tagline2 = df_post[df_post['id'] == post_id_2]['tagline'].iloc[0]
    print(tagline1)
    print("***")
    print(tagline2)
    print('similarity:', model.get_similarity(post_id_1, post_id_2))
    print(" ")
# Out:
# Professional network to share industry news and analysis
# ***
# Enhance your lifestyle with legal cannabinoids
# similarity: 0.02911420978274315
#
# Professional network to share industry news and analysis
# ***
# Code hosting & project management software
# similarity: 0.051467137915663486
#
# Professional network to share industry news and analysis
# ***
# Facebook and Linkedin group analytics
# similarity: 0.02347262634065106
#
# Professional network to share industry news and analysis
# ***
# Taking your Android screenshots to a whole new level
# similarity: 0.006460627768351879
#
# Professional network to share industry news and analysis
# ***
# Automatic page load progress bars (pure CSS)
# similarity: 0.038049823986281206
#
# Professional network to share industry news and analysis
# ***
# A tool that converts Objective-C to Swift
# similarity: 0.05436890118370441
#
# Professional network to share industry news and analysis
# ***
# 360° panoramic video camera
# ...
